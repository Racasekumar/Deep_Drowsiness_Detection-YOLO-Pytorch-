# %% [markdown]
# ## Install and Import Dependencies

# %%
# !pip3 install torch==1.8.2 torchvision==0.9.2 torchaudio===0.8.2 --extra-index-url https://download.pytorch.org/whl/lts/1.8/cpu

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
cd yolov5
# Out:
# C:\Users\Rakesh Rout\Desktop\Drowsiness_Detection\yolov5\yolov5

# %%
# !pip install -r requirements.txt

# %%
# !pip install matplotlib

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import cv2

# %% [markdown]
# ## Load Model

# %%
model = torch.hub.load("ultralytics/yolov5","yolov5s")
# Out:
# Using cache found in C:\Users\Rakesh Rout/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-8-15 Python-3.9.7 torch-1.8.2+cpu CPU
#
# ...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): Model(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %% [markdown]
# ## Train

# %%
import uuid  ## Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join(r"C:\Users\Rakesh Rout\Dropbox\PC\Desktop\Drowsiness_Detection\data\images") #/data/images
labels = ['awake', 'drowsy']
number_imgs = 20

# %%
cap=cv2.VideoCapture(0)
# loop through labels
for label in labels:
    print("Collecting images for {}" .format(label))
    time.sleep(5)
    
    # loop through image range
    for img_num in range(number_imgs):
        print("Collecting images for {}, image number {} ".format(label,img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+"."+str(uuid.uuid1())+".jpg")
        
        # Writes out image path
        cv2.imwrite(imgname,frame)
              
        # Render to the screen
        cv2.imshow("Image Collection", frame)
              
        # 2 second delay between Captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord("q"):
              break
cap.release()
cv2.destroyAllWindows()

# %%
print(os.path.join(IMAGES_PATH, label[0]+"."+str(uuid.uuid1())+".jpg"))
# Out:
# C:\Users\Rakesh Rout\Dropbox\PC\Desktop\Drowsiness_Detection\data\images\d.27dca6ed-4328-11ed-b6e9-088fc302a8ea.jpg

# %%
for label in labels:
    print("Collecting images for {}".format(label))
    for img_num in range(number_imgs):
        print("Collecting images for {}, image number {}".format(label, img_num))
        imgname=os.path.join(IMAGES_PATH, label+"."+str(uuid.uuid1())+".jpg")
        print(imgname)
# Out:
# ...
# C:\Users\Rakesh Rout\Dropbox\PC\Desktop\Drowsiness_Detection\data\images\awake.25bd166e-4328-11ed-8b83-088fc302a8ea.jpg
# ...
# C:\Users\Rakesh Rout\Dropbox\PC\Desktop\Drowsiness_Detection\data\images\awake.25bd166f-4328-11ed-a8be-088fc302a8ea.jpg
# ...
# C:\Users\Rakesh Rout\Dropbox\PC\Desktop\Drowsiness_Detection\data\images\awake.25bd1670-4328-11ed-988c-088fc302a8ea.jpg
# ...
# C:\Users\Rakesh Rout\Dropbox\PC\Desktop\Drowsiness_Detection\data\images\awake.25bd1671-4328-11ed-a41e-088fc302a8ea.jpg
# ...
# C:\Users\Rakesh Rout\Dropbox\PC\Desktop\Drowsiness_Detection\data\images\awake.25bd1672-4328-11ed-91f8-088fc302a8ea.jpg
# ...
# C:\Users\Rakesh Rout\Dropbox\PC\Desktop\Drowsiness_Detection\data\images\awake.25bd1673-4328-11ed-90e2-088fc302a8ea.jpg
# ...
# C:\Users\Rakesh Rout\Dropbox\PC\Desktop\Drowsiness_Detection\data\images\awake.25bd1674-4328-11ed-99f8-088fc302a8ea.jpg
# ...
# C:\Users\Rakesh Rout\Dropbox\PC\Desktop\Drowsiness_Detection\data\images\awake.25bd1675-4328-11ed-9488-088fc302a8ea.jpg
# ...

# %%
cd C:\Users\Rakesh Rout\Dropbox\PC\Desktop\Drowsiness_Detection\yolov5
# Out:
# C:\Users\Rakesh Rout\Dropbox\PC\Desktop\Drowsiness_Detection\yolov5

# %%
# !python train.py --img 100 --batch 20 --epochs 20 --data dataset.yaml --weights yolov5s.pt --workers 1
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=20, batch_size=20, imgsz=100, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=1, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# fatal: cannot change to 'C:\Users\Rakesh': No such file or directory
# YOLOv5  2022-10-3 Python-3.9.13 torch-1.8.2+cpu CPU
#
# ...

# %% [markdown]
# ## Load Costum Model

# %%
model = torch.hub.load('ultralytics/yolov5',"custom", path='C:\\Users\\Rakesh Rout\\Dropbox\\PC\\Desktop\\Drowsiness_Detection\\yolov5\\runs\\train\\exp4\\weights\\last.pt',force_reload=True)

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
